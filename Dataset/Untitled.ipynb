# %%
import pandas as pd

# %%
data = pd.read_csv("dataset.csv")

# %%
data
# Out:
#     tipologia genere  bagni  cucina  salotto  terrazzi/balcone        zona  \
# 0     singola      F      1       1        1                 0  San Donato
# 1     singola    M/F      1       1        1                 0     Marconi
# 2     singola    M/F      1       1        1                 0       Saffi
# 3     singola      F      2       1        1                 1     Irnerio
# 4     singola      F      1       1        0                 1    S.Vitale
# ..        ...    ...    ...     ...      ...               ...         ...
# 195    doppia    M/F      1       1        0                 2   Bolognina
# 196    doppia    M/F      2       1        1                 0    Malpighi
# 197    doppia    M/F      1       1        1                 0   Bolognina
# 198    doppia      F      1       1        1                 0    Malpighi
# 199    doppia      F      1       1        0                 0     Galvani
#
#      Prezzo €
# 0         320
# 1         465
# 2         430
# ...
